# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
import statsmodels.api as sm
import itertools
from matplotlib.pylab import rcParams
plt.style.use('ggplot')
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Import time series

# %%
import pickle
with open('./data/melted_zip6.pickle', 'rb') as file:
    melted_zip6 = pickle.load(file)

# %% [markdown]
# # ARIMA Modeling

# %%
melted_zip6.head()
# Out:
#               value
# time
# 1996-04-01  46300.0
# 1996-05-01  46500.0
# 1996-06-01  46600.0
# 1996-07-01  46700.0
# 1996-08-01  46800.0

# %%
ts1 = melted_zip6['2010-01-01':]
ts1
# Out:
#               value
# time
# 2010-01-01  71400.0
# 2010-02-01  71400.0
# 2010-03-01  70700.0
# 2010-04-01  70200.0
# 2010-05-01  70600.0
# ...             ...
# 2017-12-01  89500.0
# 2018-01-01  91900.0
# 2018-02-01  92500.0
# 2018-03-01  92600.0
# 2018-04-01  93600.0
#
# [100 rows x 1 columns]

# %%
#ts1 = melted_zip2['value'].resample('MS').mean()
ts1 = ts1.fillna(ts1.bfill())
ts1.plot(figsize=(15,6))
plt.show()

print(ts1.head())
# Out:
#               value
# time
# 2010-01-01  71400.0
# 2010-02-01  71400.0
# 2010-03-01  70700.0
# 2010-04-01  70200.0
# 2010-05-01  70600.0

# %%
warnings.filterwarnings('ignore')
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 3)  

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
pdqs = [(x[0], x[1], x[2], 1) for x in list(itertools.product(p, d, q))]

# %%
warnings.filterwarnings('ignore')
# Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
        try:
            mod = sm.tsa.statespace.SARIMAX(ts1,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            output = mod.fit()
            ans.append([comb, combs, output.aic])
            print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
        except:
            continue
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 1)12 : AIC Calculated =2538.86096827664
# ARIMA (0, 0, 0) x (0, 0, 1, 1)12 : AIC Calculated =2445.1241142505482
# ARIMA (0, 0, 0) x (0, 0, 2, 1)12 : AIC Calculated =2374.344631710899
# ARIMA (0, 0, 0) x (0, 1, 0, 1)12 : AIC Calculated =1521.488503958027
# ARIMA (0, 0, 0) x (0, 1, 1, 1)12 : AIC Calculated =1421.9169132496081
# ARIMA (0, 0, 0) x (0, 1, 2, 1)12 : AIC Calculated =1376.7799823632263
# ARIMA (0, 0, 0) x (0, 2, 0, 1)12 : AIC Calculated =1431.541051255635
# ARIMA (0, 0, 0) x (0, 2, 1, 1)12 : AIC Calculated =1406.300607104185
# ARIMA (0, 0, 0) x (0, 2, 2, 1)12 : AIC Calculated =1362.233642343166
# ARIMA (0, 0, 0) x (1, 0, 0, 1)12 : AIC Calculated =1500.8905297377592
# ARIMA (0, 0, 0) x (1, 0, 1, 1)12 : AIC Calculated =1413.1055390387417
# ARIMA (0, 0, 0) x (1, 0, 2, 1)12 : AIC Calculated =1380.642642343757
# ARIMA (0, 0, 0) x (1, 1, 0, 1)12 : AIC Calculated =1441.3204414550003
# ARIMA (0, 0, 0) x (1, 1, 1, 1)12 : AIC Calculated =1400.7110716574953
# ARIMA (0, 0, 0) x (1, 1, 2, 1)12 : AIC Calculated =1378.921185707355
# ARIMA (0, 0, 0) x (1, 2, 0, 1)12 : AIC Calculated =1431.6399390312426
# ARIMA (0, 0, 0) x (1, 2, 1, 1)12 : AIC Calculated =1402.6331437263896
# ARIMA (0, 0, 0) x (1, 2, 2, 1)12 : AIC Calculated =1358.7302993878952
# ARIMA (0, 0, 0) x (2, 0, 0, 1)12 : AIC Calculated =1436.9160497678513
# ARIMA (0, 0, 0) x (2, 0, 1, 1)12 : AIC Calculated =1409.4240342378137
# ARIMA (0, 0, 0) x (2, 0, 2, 1)12 : AIC Calculated =1382.6042904126741
# ARIMA (0, 0, 0) x (2, 1, 0, 1)12 : AIC Calculated =1414.4924412562132
# ARIMA (0, 0, 0) x (2, 1, 1, 1)12 : AIC Calculated =1398.1734972919899
# ARIMA (0, 0, 0) x (2, 1, 2, 1)12 : AIC Calculated =1378.5124814892647
# ARIMA (0, 0, 0) x (2, 2, 0, 1)12 : AIC Calculated =1373.0297873463624
# ARIMA (0, 0, 0) x (2, 2, 1, 1)12 : AIC Calculated =1374.7203100517465
# ARIMA (0, 0, 0) x (2, 2, 2, 1)12 : AIC Calculated =1358.799234680279
# ARIMA (0, 0, 1) x (0, 0, 0, 1)12 : AIC Calculated =2445.1241142505482
# ARIMA (0, 0, 1) x (0, 0, 1, 1)12 : AIC Calculated =2408.4002968177906
# ARIMA (0, 0, 1) x (0, 0, 2, 1)12 : AIC Calculated =3084.1893323971353
# ARIMA (0, 0, 1) x (0, 1, 0, 1)12 : AIC Calculated =1421.9169132496081
# ARIMA (0, 0, 1) x (0, 1, 1, 1)12 : AIC Calculated =1385.7525176367267
# ARIMA (0, 0, 1) x (0, 1, 2, 1)12 : AIC Calculated =1365.2571629466072
# ARIMA (0, 0, 1) x (0, 2, 0, 1)12 : AIC Calculated =1406.300607104185
# ARIMA (0, 0, 1) x (0, 2, 1, 1)12 : AIC Calculated =1395.0747326720648
# ARIMA (0, 0, 1) x (0, 2, 2, 1)12 : AIC Calculated =1343.2608858010383
# ARIMA (0, 0, 1) x (1, 0, 0, 1)12 : AIC Calculated =2419.9874853226443
# ARIMA (0, 0, 1) x (1, 0, 1, 1)12 : AIC Calculated =1420.1401158915453
# ARIMA (0, 0, 1) x (1, 0, 2, 1)12 : AIC Calculated =2374.6518451783368
# ARIMA (0, 0, 1) x (1, 1, 0, 1)12 : AIC Calculated =1400.7017312520618
# ARIMA (0, 0, 1) x (1, 1, 1, 1)12 : AIC Calculated =1381.5769957009084
# ARIMA (0, 0, 1) x (1, 1, 2, 1)12 : AIC Calculated =1361.8066781700759
# ARIMA (0, 0, 1) x (1, 2, 0, 1)12 : AIC Calculated =1402.6331437652623
# ARIMA (0, 0, 1) x (1, 2, 1, 1)12 : AIC Calculated =1358.7302993994456
# ARIMA (0, 0, 1) x (1, 2, 2, 1)12 : AIC Calculated =1344.6150859261502
# ARIMA (0, 0, 1) x (2, 0, 0, 1)12 : AIC Calculated =2421.9870117906144
# ARIMA (0, 0, 1) x (2, 0, 1, 1)12 : AIC Calculated =2399.3543682458953
# ARIMA (0, 0, 1) x (2, 0, 2, 1)12 : AIC Calculated =2376.7223718692894
# ARIMA (0, 0, 1) x (2, 1, 0, 1)12 : AIC Calculated =1398.173497279918
# ARIMA (0, 0, 1) x (2, 1, 1, 1)12 : AIC Calculated =1385.238732549847
# ARIMA (0, 0, 1) x (2, 1, 2, 1)12 : AIC Calculated =1362.5752535753415
# ARIMA (0, 0, 1) x (2, 2, 0, 1)12 : AIC Calculated =1374.7185201327627
# ARIMA (0, 0, 1) x (2, 2, 1, 1)12 : AIC Calculated =1358.7924701776583
# ARIMA (0, 0, 1) x (2, 2, 2, 1)12 : AIC Calculated =1338.9332891947565
# ARIMA (0, 0, 2) x (0, 0, 0, 1)12 : AIC Calculated =2374.344631710899
# ARIMA (0, 0, 2) x (0, 0, 1, 1)12 : AIC Calculated =3085.689882283278
# ARIMA (0, 0, 2) x (0, 0, 2, 1)12 : AIC Calculated =9833.65334344511
# ARIMA (0, 0, 2) x (0, 1, 0, 1)12 : AIC Calculated =1376.7799823632263
# ARIMA (0, 0, 2) x (0, 1, 1, 1)12 : AIC Calculated =1365.2825476325863
# ARIMA (0, 0, 2) x (0, 1, 2, 1)12 : AIC Calculated =1351.9449751205548
# ARIMA (0, 0, 2) x (0, 2, 0, 1)12 : AIC Calculated =1362.233642343166
# ARIMA (0, 0, 2) x (0, 2, 1, 1)12 : AIC Calculated =1343.2608859749234
# ARIMA (0, 0, 2) x (0, 2, 2, 1)12 : AIC Calculated =1339.221956313327
# ARIMA (0, 0, 2) x (1, 0, 0, 1)12 : AIC Calculated =2381.7354109556836
# ARIMA (0, 0, 2) x (1, 0, 1, 1)12 : AIC Calculated =2375.734840622482
# ARIMA (0, 0, 2) x (1, 0, 2, 1)12 : AIC Calculated =2353.091811033092
# ARIMA (0, 0, 2) x (1, 1, 0, 1)12 : AIC Calculated =1378.5253427664748
# ARIMA (0, 0, 2) x (1, 1, 1, 1)12 : AIC Calculated =1367.2120157569834
# ARIMA (0, 0, 2) x (1, 1, 2, 1)12 : AIC Calculated =1345.8245191779013
# ARIMA (0, 0, 2) x (1, 2, 0, 1)12 : AIC Calculated =1358.730299592963
# ARIMA (0, 0, 2) x (1, 2, 1, 1)12 : AIC Calculated =1344.6150860085875
# ARIMA (0, 0, 2) x (1, 2, 2, 1)12 : AIC Calculated =1328.297445176699
# ARIMA (0, 0, 2) x (2, 0, 0, 1)12 : AIC Calculated =2400.3783099549246
# ARIMA (0, 0, 2) x (2, 0, 1, 1)12 : AIC Calculated =2377.734660160768
# ARIMA (0, 0, 2) x (2, 0, 2, 1)12 : AIC Calculated =2355.091002880432
# ARIMA (0, 0, 2) x (2, 1, 0, 1)12 : AIC Calculated =1380.4840874194847
# ARIMA (0, 0, 2) x (2, 1, 1, 1)12 : AIC Calculated =1368.279142312043
# ARIMA (0, 0, 2) x (2, 1, 2, 1)12 : AIC Calculated =1345.1402976448574
# ARIMA (0, 0, 2) x (2, 2, 0, 1)12 : AIC Calculated =1358.792470055238
# ARIMA (0, 0, 2) x (2, 2, 1, 1)12 : AIC Calculated =1338.9332894139839
# ARIMA (0, 0, 2) x (2, 2, 2, 1)12 : AIC Calculated =1327.4412817379837
# ARIMA (0, 1, 0) x (0, 0, 0, 1)12 : AIC Calculated =1521.488503958027
# ARIMA (0, 1, 0) x (0, 0, 1, 1)12 : AIC Calculated =1421.9169132496081
# ARIMA (0, 1, 0) x (0, 0, 2, 1)12 : AIC Calculated =1376.7799823632263
# ARIMA (0, 1, 0) x (0, 1, 0, 1)12 : AIC Calculated =1431.541051255635
# ARIMA (0, 1, 0) x (0, 1, 1, 1)12 : AIC Calculated =1406.300607104185
# ARIMA (0, 1, 0) x (0, 1, 2, 1)12 : AIC Calculated =1362.233642343166
# ARIMA (0, 1, 0) x (0, 2, 0, 1)12 : AIC Calculated =1467.681048213271
# ARIMA (0, 1, 0) x (0, 2, 1, 1)12 : AIC Calculated =1446.082780687406
# ARIMA (0, 1, 0) x (0, 2, 2, 1)12 : AIC Calculated =1375.8917511169577
# ARIMA (0, 1, 0) x (1, 0, 0, 1)12 : AIC Calculated =1441.3204414550003
# ARIMA (0, 1, 0) x (1, 0, 1, 1)12 : AIC Calculated =1400.7110716574953
# ARIMA (0, 1, 0) x (1, 0, 2, 1)12 : AIC Calculated =1378.921185707355
# ARIMA (0, 1, 0) x (1, 1, 0, 1)12 : AIC Calculated =1431.6399390312426
# ARIMA (0, 1, 0) x (1, 1, 1, 1)12 : AIC Calculated =1402.6331437263896
# ARIMA (0, 1, 0) x (1, 1, 2, 1)12 : AIC Calculated =1358.7302993878952
# ARIMA (0, 1, 0) x (1, 2, 0, 1)12 : AIC Calculated =1469.3717211322419
# ARIMA (0, 1, 0) x (1, 2, 1, 1)12 : AIC Calculated =1424.2221587323347
# ARIMA (0, 1, 0) x (1, 2, 2, 1)12 : AIC Calculated =1377.8903626526646
# ARIMA (0, 1, 0) x (2, 0, 0, 1)12 : AIC Calculated =1414.4924412562132
# ARIMA (0, 1, 0) x (2, 0, 1, 1)12 : AIC Calculated =1398.1734972919899
# ARIMA (0, 1, 0) x (2, 0, 2, 1)12 : AIC Calculated =1378.5124814892647
# ARIMA (0, 1, 0) x (2, 1, 0, 1)12 : AIC Calculated =1373.0297873463624
# ARIMA (0, 1, 0) x (2, 1, 1, 1)12 : AIC Calculated =1374.7203100517465
# ARIMA (0, 1, 0) x (2, 1, 2, 1)12 : AIC Calculated =1358.799234680279
# ARIMA (0, 1, 0) x (2, 2, 0, 1)12 : AIC Calculated =1398.6642901428568
# ARIMA (0, 1, 0) x (2, 2, 1, 1)12 : AIC Calculated =1400.3459199709473
# ARIMA (0, 1, 0) x (2, 2, 2, 1)12 : AIC Calculated =1371.1457095541882
# ARIMA (0, 1, 1) x (0, 0, 0, 1)12 : AIC Calculated =1421.9169132496081
# ARIMA (0, 1, 1) x (0, 0, 1, 1)12 : AIC Calculated =1385.7525176367267
# ARIMA (0, 1, 1) x (0, 0, 2, 1)12 : AIC Calculated =1365.2571629466072
# ARIMA (0, 1, 1) x (0, 1, 0, 1)12 : AIC Calculated =1406.300607104185
# ARIMA (0, 1, 1) x (0, 1, 1, 1)12 : AIC Calculated =1395.0747326720648
# ARIMA (0, 1, 1) x (0, 1, 2, 1)12 : AIC Calculated =1343.2608858010383
# ARIMA (0, 1, 1) x (0, 2, 0, 1)12 : AIC Calculated =1446.082780687406
# ARIMA (0, 1, 1) x (0, 2, 1, 1)12 : AIC Calculated =1421.100649883697
# ARIMA (0, 1, 1) x (0, 2, 2, 1)12 : AIC Calculated =1340.6710504453797
# ARIMA (0, 1, 1) x (1, 0, 0, 1)12 : AIC Calculated =1400.7017312520618
# ARIMA (0, 1, 1) x (1, 0, 1, 1)12 : AIC Calculated =1381.5769957009084
# ARIMA (0, 1, 1) x (1, 0, 2, 1)12 : AIC Calculated =1361.8066781700759
# ARIMA (0, 1, 1) x (1, 1, 0, 1)12 : AIC Calculated =1402.6331437652623
# ARIMA (0, 1, 1) x (1, 1, 1, 1)12 : AIC Calculated =1358.7302993994456
# ARIMA (0, 1, 1) x (1, 1, 2, 1)12 : AIC Calculated =1344.6150859261502
# ARIMA (0, 1, 1) x (1, 2, 0, 1)12 : AIC Calculated =1424.222158754128
# ARIMA (0, 1, 1) x (1, 2, 1, 1)12 : AIC Calculated =1377.8903626669671
# ARIMA (0, 1, 1) x (1, 2, 2, 1)12 : AIC Calculated =1338.5263714263103
# ARIMA (0, 1, 1) x (2, 0, 0, 1)12 : AIC Calculated =1398.173497279918
# ARIMA (0, 1, 1) x (2, 0, 1, 1)12 : AIC Calculated =1385.238732549847
# ARIMA (0, 1, 1) x (2, 0, 2, 1)12 : AIC Calculated =1362.5752535753415
# ARIMA (0, 1, 1) x (2, 1, 0, 1)12 : AIC Calculated =1374.7185201327627
# ARIMA (0, 1, 1) x (2, 1, 1, 1)12 : AIC Calculated =1358.7924701776583
# ARIMA (0, 1, 1) x (2, 1, 2, 1)12 : AIC Calculated =1338.9332891947565
# ARIMA (0, 1, 1) x (2, 2, 0, 1)12 : AIC Calculated =1400.3459198373632
# ARIMA (0, 1, 1) x (2, 2, 1, 1)12 : AIC Calculated =1381.8758595376114
# ARIMA (0, 1, 1) x (2, 2, 2, 1)12 : AIC Calculated =1364.1103408074216
# ARIMA (0, 1, 2) x (0, 0, 0, 1)12 : AIC Calculated =1376.7799823632263
# ARIMA (0, 1, 2) x (0, 0, 1, 1)12 : AIC Calculated =1365.2825476325863
# ARIMA (0, 1, 2) x (0, 0, 2, 1)12 : AIC Calculated =1351.9449751205548
# ARIMA (0, 1, 2) x (0, 1, 0, 1)12 : AIC Calculated =1362.233642343166
# ARIMA (0, 1, 2) x (0, 1, 1, 1)12 : AIC Calculated =1343.2608859749234
# ARIMA (0, 1, 2) x (0, 1, 2, 1)12 : AIC Calculated =1339.221956313327
# ARIMA (0, 1, 2) x (0, 2, 0, 1)12 : AIC Calculated =1375.8917511169577
# ARIMA (0, 1, 2) x (0, 2, 1, 1)12 : AIC Calculated =1340.6710508404037
# ARIMA (0, 1, 2) x (0, 2, 2, 1)12 : AIC Calculated =1326.8893452030832
# ARIMA (0, 1, 2) x (1, 0, 0, 1)12 : AIC Calculated =1378.5253427664748
# ARIMA (0, 1, 2) x (1, 0, 1, 1)12 : AIC Calculated =1367.2120157569834
# ARIMA (0, 1, 2) x (1, 0, 2, 1)12 : AIC Calculated =1345.8245191779013
# ARIMA (0, 1, 2) x (1, 1, 0, 1)12 : AIC Calculated =1358.730299592963
# ARIMA (0, 1, 2) x (1, 1, 1, 1)12 : AIC Calculated =1344.6150860085875
# ARIMA (0, 1, 2) x (1, 1, 2, 1)12 : AIC Calculated =1328.297445176699
# ARIMA (0, 1, 2) x (1, 2, 0, 1)12 : AIC Calculated =1377.8903629696242
# ARIMA (0, 1, 2) x (1, 2, 1, 1)12 : AIC Calculated =1338.5263714007972
# ARIMA (0, 1, 2) x (1, 2, 2, 1)12 : AIC Calculated =1326.3310190281225
# ARIMA (0, 1, 2) x (2, 0, 0, 1)12 : AIC Calculated =1380.4840874194847
# ARIMA (0, 1, 2) x (2, 0, 1, 1)12 : AIC Calculated =1368.279142312043
# ARIMA (0, 1, 2) x (2, 0, 2, 1)12 : AIC Calculated =1345.1402976448574
# ARIMA (0, 1, 2) x (2, 1, 0, 1)12 : AIC Calculated =1358.792470055238
# ARIMA (0, 1, 2) x (2, 1, 1, 1)12 : AIC Calculated =1338.9332894139839
# ARIMA (0, 1, 2) x (2, 1, 2, 1)12 : AIC Calculated =1327.4412817379837
# ARIMA (0, 1, 2) x (2, 2, 0, 1)12 : AIC Calculated =1371.1362621929427
# ARIMA (0, 1, 2) x (2, 2, 1, 1)12 : AIC Calculated =1337.858825355598
# ARIMA (0, 1, 2) x (2, 2, 2, 1)12 : AIC Calculated =1315.6176861540112
# ARIMA (0, 2, 0) x (0, 0, 0, 1)12 : AIC Calculated =1431.541051255635
# ARIMA (0, 2, 0) x (0, 0, 1, 1)12 : AIC Calculated =1406.300607104185
# ARIMA (0, 2, 0) x (0, 0, 2, 1)12 : AIC Calculated =1362.233642343166
# ARIMA (0, 2, 0) x (0, 1, 0, 1)12 : AIC Calculated =1467.681048213271
# ARIMA (0, 2, 0) x (0, 1, 1, 1)12 : AIC Calculated =1446.082780687406
# ARIMA (0, 2, 0) x (0, 1, 2, 1)12 : AIC Calculated =1375.8917511169577
# ARIMA (0, 2, 0) x (0, 2, 0, 1)12 : AIC Calculated =1512.174479462263
# ARIMA (0, 2, 0) x (0, 2, 1, 1)12 : AIC Calculated =1460.1298759811693
# ARIMA (0, 2, 0) x (0, 2, 2, 1)12 : AIC Calculated =1451.4095865909728
# ARIMA (0, 2, 0) x (1, 0, 0, 1)12 : AIC Calculated =1431.6399390312426
# ARIMA (0, 2, 0) x (1, 0, 1, 1)12 : AIC Calculated =1402.6331437263896
# ARIMA (0, 2, 0) x (1, 0, 2, 1)12 : AIC Calculated =1358.7302993878952
# ARIMA (0, 2, 0) x (1, 1, 0, 1)12 : AIC Calculated =1469.3717211322419
# ARIMA (0, 2, 0) x (1, 1, 1, 1)12 : AIC Calculated =1424.2221587323347
# ARIMA (0, 2, 0) x (1, 1, 2, 1)12 : AIC Calculated =1377.8903626526646
# ARIMA (0, 2, 0) x (1, 2, 0, 1)12 : AIC Calculated =1511.3763172104393
# ARIMA (0, 2, 0) x (1, 2, 1, 1)12 : AIC Calculated =1461.8462249947397
# ARIMA (0, 2, 0) x (1, 2, 2, 1)12 : AIC Calculated =1448.0060882581624
# ARIMA (0, 2, 0) x (2, 0, 0, 1)12 : AIC Calculated =1373.0297873463624
# ARIMA (0, 2, 0) x (2, 0, 1, 1)12 : AIC Calculated =1374.7203100517465
# ARIMA (0, 2, 0) x (2, 0, 2, 1)12 : AIC Calculated =1358.799234680279
# ARIMA (0, 2, 0) x (2, 1, 0, 1)12 : AIC Calculated =1398.6642901428568
# ARIMA (0, 2, 0) x (2, 1, 1, 1)12 : AIC Calculated =1400.3459199709473
# ARIMA (0, 2, 0) x (2, 1, 2, 1)12 : AIC Calculated =1371.1457095541882
# ARIMA (0, 2, 0) x (2, 2, 0, 1)12 : AIC Calculated =1449.7549728752679
# ARIMA (0, 2, 0) x (2, 2, 1, 1)12 : AIC Calculated =1442.5379687843374
# ARIMA (0, 2, 0) x (2, 2, 2, 1)12 : AIC Calculated =1419.2140743111663
# ARIMA (0, 2, 1) x (0, 0, 0, 1)12 : AIC Calculated =1406.300607104185
# ARIMA (0, 2, 1) x (0, 0, 1, 1)12 : AIC Calculated =1395.0747326720648
# ARIMA (0, 2, 1) x (0, 0, 2, 1)12 : AIC Calculated =1343.2608858010383
# ARIMA (0, 2, 1) x (0, 1, 0, 1)12 : AIC Calculated =1446.082780687406
# ARIMA (0, 2, 1) x (0, 1, 1, 1)12 : AIC Calculated =1421.100649883697
# ARIMA (0, 2, 1) x (0, 1, 2, 1)12 : AIC Calculated =1340.6710504453797
# ARIMA (0, 2, 1) x (0, 2, 0, 1)12 : AIC Calculated =1460.1298759811693
# ARIMA (0, 2, 1) x (0, 2, 1, 1)12 : AIC Calculated =1459.035282650708
# ARIMA (0, 2, 1) x (0, 2, 2, 1)12 : AIC Calculated =1371.8188967391288
# ARIMA (0, 2, 1) x (1, 0, 0, 1)12 : AIC Calculated =1402.6331437652623
# ARIMA (0, 2, 1) x (1, 0, 1, 1)12 : AIC Calculated =1358.7302993994456
# ARIMA (0, 2, 1) x (1, 0, 2, 1)12 : AIC Calculated =1344.6150859261502
# ARIMA (0, 2, 1) x (1, 1, 0, 1)12 : AIC Calculated =1424.222158754128
# ARIMA (0, 2, 1) x (1, 1, 1, 1)12 : AIC Calculated =1377.8903626669671
# ARIMA (0, 2, 1) x (1, 1, 2, 1)12 : AIC Calculated =1338.5263714263103
# ARIMA (0, 2, 1) x (1, 2, 0, 1)12 : AIC Calculated =1462.1276437547178
# ARIMA (0, 2, 1) x (1, 2, 1, 1)12 : AIC Calculated =1446.3330747268728
# ARIMA (0, 2, 1) x (1, 2, 2, 1)12 : AIC Calculated =1366.1268006949558
# ARIMA (0, 2, 1) x (2, 0, 0, 1)12 : AIC Calculated =1374.7185201327627
# ARIMA (0, 2, 1) x (2, 0, 1, 1)12 : AIC Calculated =1358.7924701776583
# ARIMA (0, 2, 1) x (2, 0, 2, 1)12 : AIC Calculated =1338.9332891947565
# ARIMA (0, 2, 1) x (2, 1, 0, 1)12 : AIC Calculated =1400.3459198373632
# ARIMA (0, 2, 1) x (2, 1, 1, 1)12 : AIC Calculated =1381.8758595376114
# ARIMA (0, 2, 1) x (2, 1, 2, 1)12 : AIC Calculated =1364.1103408074216
# ARIMA (0, 2, 1) x (2, 2, 0, 1)12 : AIC Calculated =1442.1749365884357
# ARIMA (0, 2, 1) x (2, 2, 1, 1)12 : AIC Calculated =1419.272614429078
# ARIMA (0, 2, 1) x (2, 2, 2, 1)12 : AIC Calculated =1396.1214837169634
# ARIMA (0, 2, 2) x (0, 0, 0, 1)12 : AIC Calculated =1362.233642343166
# ARIMA (0, 2, 2) x (0, 0, 1, 1)12 : AIC Calculated =1343.2608859749234
# ARIMA (0, 2, 2) x (0, 0, 2, 1)12 : AIC Calculated =1339.221956313327
# ARIMA (0, 2, 2) x (0, 1, 0, 1)12 : AIC Calculated =1375.8917511169577
# ARIMA (0, 2, 2) x (0, 1, 1, 1)12 : AIC Calculated =1340.6710508404037
# ARIMA (0, 2, 2) x (0, 1, 2, 1)12 : AIC Calculated =1326.8893452030832
# ARIMA (0, 2, 2) x (0, 2, 0, 1)12 : AIC Calculated =1451.4095865909728
# ARIMA (0, 2, 2) x (0, 2, 1, 1)12 : AIC Calculated =1371.8188967000085
# ARIMA (0, 2, 2) x (0, 2, 2, 1)12 : AIC Calculated =1355.7986524385424
# ARIMA (0, 2, 2) x (1, 0, 0, 1)12 : AIC Calculated =1358.730299592963
# ARIMA (0, 2, 2) x (1, 0, 1, 1)12 : AIC Calculated =1344.6150860085875
# ARIMA (0, 2, 2) x (1, 0, 2, 1)12 : AIC Calculated =1328.297445176699
# ARIMA (0, 2, 2) x (1, 1, 0, 1)12 : AIC Calculated =1377.8903629696242
# ARIMA (0, 2, 2) x (1, 1, 1, 1)12 : AIC Calculated =1338.5263714007972
# ARIMA (0, 2, 2) x (1, 1, 2, 1)12 : AIC Calculated =1326.3310190281225
# ARIMA (0, 2, 2) x (1, 2, 0, 1)12 : AIC Calculated =1448.006088250511
# ARIMA (0, 2, 2) x (1, 2, 1, 1)12 : AIC Calculated =1366.1268007147298
# ARIMA (0, 2, 2) x (1, 2, 2, 1)12 : AIC Calculated =1335.160342513807
# ARIMA (0, 2, 2) x (2, 0, 0, 1)12 : AIC Calculated =1358.792470055238
# ARIMA (0, 2, 2) x (2, 0, 1, 1)12 : AIC Calculated =1338.9332894139839
# ARIMA (0, 2, 2) x (2, 0, 2, 1)12 : AIC Calculated =1327.4412817379837
# ARIMA (0, 2, 2) x (2, 1, 0, 1)12 : AIC Calculated =1371.1362621929427
# ARIMA (0, 2, 2) x (2, 1, 1, 1)12 : AIC Calculated =1337.858825355598
# ARIMA (0, 2, 2) x (2, 1, 2, 1)12 : AIC Calculated =1315.6176861540112
# ARIMA (0, 2, 2) x (2, 2, 0, 1)12 : AIC Calculated =1419.2726144292237
# ARIMA (0, 2, 2) x (2, 2, 1, 1)12 : AIC Calculated =1348.5195311620093
# ARIMA (0, 2, 2) x (2, 2, 2, 1)12 : AIC Calculated =1344.8477415876407
# ARIMA (1, 0, 0) x (0, 0, 0, 1)12 : AIC Calculated =1500.8905297377592
# ARIMA (1, 0, 0) x (0, 0, 1, 1)12 : AIC Calculated =1413.0596737271378
# ARIMA (1, 0, 0) x (0, 0, 2, 1)12 : AIC Calculated =1415.1493459191186
# ARIMA (1, 0, 0) x (0, 1, 0, 1)12 : AIC Calculated =1441.3204414550003
# ARIMA (1, 0, 0) x (0, 1, 1, 1)12 : AIC Calculated =1400.7017312531866
# ARIMA (1, 0, 0) x (0, 1, 2, 1)12 : AIC Calculated =1378.525342851604
# ARIMA (1, 0, 0) x (0, 2, 0, 1)12 : AIC Calculated =1431.6399390312426
# ARIMA (1, 0, 0) x (0, 2, 1, 1)12 : AIC Calculated =1402.6331437902077
# ARIMA (1, 0, 0) x (0, 2, 2, 1)12 : AIC Calculated =1358.7302993897908
# ARIMA (1, 0, 0) x (1, 0, 0, 1)12 : AIC Calculated =1449.8361182936494
# ARIMA (1, 0, 0) x (1, 0, 1, 1)12 : AIC Calculated =1446.3800103877188
# ARIMA (1, 0, 0) x (1, 0, 2, 1)12 : AIC Calculated =1382.594432577609
# ARIMA (1, 0, 0) x (1, 1, 0, 1)12 : AIC Calculated =1417.4013746496626
# ARIMA (1, 0, 0) x (1, 1, 1, 1)12 : AIC Calculated =1419.0618718250555
# ARIMA (1, 0, 0) x (1, 1, 2, 1)12 : AIC Calculated =1380.5211527688916
# ARIMA (1, 0, 0) x (1, 2, 0, 1)12 : AIC Calculated =1419.0982880007552
# ARIMA (1, 0, 0) x (1, 2, 1, 1)12 : AIC Calculated =1404.4519659933524
# ARIMA (1, 0, 0) x (1, 2, 2, 1)12 : AIC Calculated =1360.6958393420782
# ARIMA (1, 0, 0) x (2, 0, 0, 1)12 : AIC Calculated =1420.703549367446
# ARIMA (1, 0, 0) x (2, 0, 1, 1)12 : AIC Calculated =1420.3140563167422
# ARIMA (1, 0, 0) x (2, 0, 2, 1)12 : AIC Calculated =1418.305653630363
# ARIMA (1, 0, 0) x (2, 1, 0, 1)12 : AIC Calculated =1372.6164384029719
# ARIMA (1, 0, 0) x (2, 1, 1, 1)12 : AIC Calculated =1385.041261360101
# ARIMA (1, 0, 0) x (2, 1, 2, 1)12 : AIC Calculated =1371.939175543495
# ARIMA (1, 0, 0) x (2, 2, 0, 1)12 : AIC Calculated =1360.9761475563473
# ARIMA (1, 0, 0) x (2, 2, 1, 1)12 : AIC Calculated =1360.3998208178043
# ARIMA (1, 0, 0) x (2, 2, 2, 1)12 : AIC Calculated =1352.6675454436088
# ARIMA (1, 0, 1) x (0, 0, 0, 1)12 : AIC Calculated =1413.1055390387417
# ARIMA (1, 0, 1) x (0, 0, 1, 1)12 : AIC Calculated =1386.2236616556672
# ARIMA (1, 0, 1) x (0, 0, 2, 1)12 : AIC Calculated =1387.2893542024394
# ARIMA (1, 0, 1) x (0, 1, 0, 1)12 : AIC Calculated =1400.7110716574953
# ARIMA (1, 0, 1) x (0, 1, 1, 1)12 : AIC Calculated =1381.576999120337
# ARIMA (1, 0, 1) x (0, 1, 2, 1)12 : AIC Calculated =1367.2120152301404
# ARIMA (1, 0, 1) x (0, 2, 0, 1)12 : AIC Calculated =1402.6331437263896
# ARIMA (1, 0, 1) x (0, 2, 1, 1)12 : AIC Calculated =1358.730299402446
# ARIMA (1, 0, 1) x (0, 2, 2, 1)12 : AIC Calculated =1344.615085962102
# ARIMA (1, 0, 1) x (1, 0, 0, 1)12 : AIC Calculated =1409.461428884284
# ARIMA (1, 0, 1) x (1, 0, 1, 1)12 : AIC Calculated =1425.6671819956364
# ARIMA (1, 0, 1) x (1, 0, 2, 1)12 : AIC Calculated =1371.5338944976622
# ARIMA (1, 0, 1) x (1, 1, 0, 1)12 : AIC Calculated =1419.0618718206906
# ARIMA (1, 0, 1) x (1, 1, 1, 1)12 : AIC Calculated =1383.255279507215
# ARIMA (1, 0, 1) x (1, 1, 2, 1)12 : AIC Calculated =1362.573540218394
# ARIMA (1, 0, 1) x (1, 2, 0, 1)12 : AIC Calculated =1404.4519659833209
# ARIMA (1, 0, 1) x (1, 2, 1, 1)12 : AIC Calculated =1386.6267096897175
# ARIMA (1, 0, 1) x (1, 2, 2, 1)12 : AIC Calculated =1346.4645362541091
# ARIMA (1, 0, 1) x (2, 0, 0, 1)12 : AIC Calculated =1391.769911200045
# ARIMA (1, 0, 1) x (2, 0, 1, 1)12 : AIC Calculated =1388.8058391335896
# ARIMA (1, 0, 1) x (2, 0, 2, 1)12 : AIC Calculated =1377.4612560372907
# ARIMA (1, 0, 1) x (2, 1, 0, 1)12 : AIC Calculated =1374.448828639565
# ARIMA (1, 0, 1) x (2, 1, 1, 1)12 : AIC Calculated =1386.140290084155
# ARIMA (1, 0, 1) x (2, 1, 2, 1)12 : AIC Calculated =1364.3945341460435
# ARIMA (1, 0, 1) x (2, 2, 0, 1)12 : AIC Calculated =1360.3998207889665
# ARIMA (1, 0, 1) x (2, 2, 1, 1)12 : AIC Calculated =1360.870160754079
# ARIMA (1, 0, 1) x (2, 2, 2, 1)12 : AIC Calculated =1340.7629032286518
# ARIMA (1, 0, 2) x (0, 0, 0, 1)12 : AIC Calculated =1380.642642343757
# ARIMA (1, 0, 2) x (0, 0, 1, 1)12 : AIC Calculated =1368.3961965901603
# ARIMA (1, 0, 2) x (0, 0, 2, 1)12 : AIC Calculated =1361.2974311829857
# ARIMA (1, 0, 2) x (0, 1, 0, 1)12 : AIC Calculated =1378.921185707355
# ARIMA (1, 0, 2) x (0, 1, 1, 1)12 : AIC Calculated =1361.2859263679056
# ARIMA (1, 0, 2) x (0, 1, 2, 1)12 : AIC Calculated =1343.0050514379275
# ARIMA (1, 0, 2) x (0, 2, 0, 1)12 : AIC Calculated =1358.7302993878952
# ARIMA (1, 0, 2) x (0, 2, 1, 1)12 : AIC Calculated =1344.6150859737527
# ARIMA (1, 0, 2) x (0, 2, 2, 1)12 : AIC Calculated =1328.4456274985032
# ARIMA (1, 0, 2) x (1, 0, 0, 1)12 : AIC Calculated =1382.6281591476884
# ARIMA (1, 0, 2) x (1, 0, 1, 1)12 : AIC Calculated =1370.213179066951
# ARIMA (1, 0, 2) x (1, 0, 2, 1)12 : AIC Calculated =1381.3011168056819
# ARIMA (1, 0, 2) x (1, 1, 0, 1)12 : AIC Calculated =1378.5124815144527
# ARIMA (1, 0, 2) x (1, 1, 1, 1)12 : AIC Calculated =1362.5735292681672
# ARIMA (1, 0, 2) x (1, 1, 2, 1)12 : AIC Calculated =1355.6793948328616
# ARIMA (1, 0, 2) x (1, 2, 0, 1)12 : AIC Calculated =1360.6958393426326
# ARIMA (1, 0, 2) x (1, 2, 1, 1)12 : AIC Calculated =1346.4645364440705
# ARIMA (1, 0, 2) x (1, 2, 2, 1)12 : AIC Calculated =1333.334167983387
# ARIMA (1, 0, 2) x (2, 0, 0, 1)12 : AIC Calculated =1383.5267633885005
# ARIMA (1, 0, 2) x (2, 0, 1, 1)12 : AIC Calculated =1372.859307190693
# ARIMA (1, 0, 2) x (2, 0, 2, 1)12 : AIC Calculated =1355.5254610675695
# ARIMA (1, 0, 2) x (2, 1, 0, 1)12 : AIC Calculated =1371.9391755229028
# ARIMA (1, 0, 2) x (2, 1, 1, 1)12 : AIC Calculated =1369.1724422904404
# ARIMA (1, 0, 2) x (2, 1, 2, 1)12 : AIC Calculated =1342.7963444679963
# ARIMA (1, 0, 2) x (2, 2, 0, 1)12 : AIC Calculated =1352.6660167252053
# ARIMA (1, 0, 2) x (2, 2, 1, 1)12 : AIC Calculated =1340.7502809504535
# ARIMA (1, 0, 2) x (2, 2, 2, 1)12 : AIC Calculated =1327.4081000325268
# ARIMA (1, 1, 0) x (0, 0, 0, 1)12 : AIC Calculated =1441.3204414550003
# ARIMA (1, 1, 0) x (0, 0, 1, 1)12 : AIC Calculated =1400.7017312531866
# ARIMA (1, 1, 0) x (0, 0, 2, 1)12 : AIC Calculated =1378.525342851604
# ARIMA (1, 1, 0) x (0, 1, 0, 1)12 : AIC Calculated =1431.6399390312426
# ARIMA (1, 1, 0) x (0, 1, 1, 1)12 : AIC Calculated =1402.6331437902077
# ARIMA (1, 1, 0) x (0, 1, 2, 1)12 : AIC Calculated =1358.7302993897908
# ARIMA (1, 1, 0) x (0, 2, 0, 1)12 : AIC Calculated =1469.3717211322419
# ARIMA (1, 1, 0) x (0, 2, 1, 1)12 : AIC Calculated =1424.2221588493514
# ARIMA (1, 1, 0) x (0, 2, 2, 1)12 : AIC Calculated =1377.8903627464583
# ARIMA (1, 1, 0) x (1, 0, 0, 1)12 : AIC Calculated =1417.4013746496626
# ARIMA (1, 1, 0) x (1, 0, 1, 1)12 : AIC Calculated =1419.0618718250555
# ARIMA (1, 1, 0) x (1, 0, 2, 1)12 : AIC Calculated =1380.5211527688916
# ARIMA (1, 1, 0) x (1, 1, 0, 1)12 : AIC Calculated =1419.0982880007552
# ARIMA (1, 1, 0) x (1, 1, 1, 1)12 : AIC Calculated =1404.4519659933524
# ARIMA (1, 1, 0) x (1, 1, 2, 1)12 : AIC Calculated =1360.6958393420782
# ARIMA (1, 1, 0) x (1, 2, 0, 1)12 : AIC Calculated =1454.757366118591
# ARIMA (1, 1, 0) x (1, 2, 1, 1)12 : AIC Calculated =1423.07462976377
# ARIMA (1, 1, 0) x (1, 2, 2, 1)12 : AIC Calculated =1379.8903269734244
# ARIMA (1, 1, 0) x (2, 0, 0, 1)12 : AIC Calculated =1372.6164384029719
# ARIMA (1, 1, 0) x (2, 0, 1, 1)12 : AIC Calculated =1385.041261360101
# ARIMA (1, 1, 0) x (2, 0, 2, 1)12 : AIC Calculated =1371.939175543495
# ARIMA (1, 1, 0) x (2, 1, 0, 1)12 : AIC Calculated =1360.9761475563473
# ARIMA (1, 1, 0) x (2, 1, 1, 1)12 : AIC Calculated =1360.3998208178043
# ARIMA (1, 1, 0) x (2, 1, 2, 1)12 : AIC Calculated =1352.6675454436088
# ARIMA (1, 1, 0) x (2, 2, 0, 1)12 : AIC Calculated =1380.4963599120706
# ARIMA (1, 1, 0) x (2, 2, 1, 1)12 : AIC Calculated =1357.2397655077893
# ARIMA (1, 1, 0) x (2, 2, 2, 1)12 : AIC Calculated =1370.5004392117448
# ARIMA (1, 1, 1) x (0, 0, 0, 1)12 : AIC Calculated =1400.7110716574953
# ARIMA (1, 1, 1) x (0, 0, 1, 1)12 : AIC Calculated =1381.576999120337
# ARIMA (1, 1, 1) x (0, 0, 2, 1)12 : AIC Calculated =1367.2120152301404
# ARIMA (1, 1, 1) x (0, 1, 0, 1)12 : AIC Calculated =1402.6331437263896
# ARIMA (1, 1, 1) x (0, 1, 1, 1)12 : AIC Calculated =1358.730299402446
# ARIMA (1, 1, 1) x (0, 1, 2, 1)12 : AIC Calculated =1344.615085962102
# ARIMA (1, 1, 1) x (0, 2, 0, 1)12 : AIC Calculated =1424.2221587323347
# ARIMA (1, 1, 1) x (0, 2, 1, 1)12 : AIC Calculated =1377.8903626978015
# ARIMA (1, 1, 1) x (0, 2, 2, 1)12 : AIC Calculated =1338.5263714074486
# ARIMA (1, 1, 1) x (1, 0, 0, 1)12 : AIC Calculated =1419.0618718206906
# ARIMA (1, 1, 1) x (1, 0, 1, 1)12 : AIC Calculated =1383.255279507215
# ARIMA (1, 1, 1) x (1, 0, 2, 1)12 : AIC Calculated =1362.573540218394
# ARIMA (1, 1, 1) x (1, 1, 0, 1)12 : AIC Calculated =1404.4519659833209
# ARIMA (1, 1, 1) x (1, 1, 1, 1)12 : AIC Calculated =1386.6267096897175
# ARIMA (1, 1, 1) x (1, 1, 2, 1)12 : AIC Calculated =1346.4645362541091
# ARIMA (1, 1, 1) x (1, 2, 0, 1)12 : AIC Calculated =1423.0746297334354
# ARIMA (1, 1, 1) x (1, 2, 1, 1)12 : AIC Calculated =1399.9810215797881
# ARIMA (1, 1, 1) x (1, 2, 2, 1)12 : AIC Calculated =1339.0595705591768
# ARIMA (1, 1, 1) x (2, 0, 0, 1)12 : AIC Calculated =1374.448828639565
# ARIMA (1, 1, 1) x (2, 0, 1, 1)12 : AIC Calculated =1386.140290084155
# ARIMA (1, 1, 1) x (2, 0, 2, 1)12 : AIC Calculated =1364.3945341460435
# ARIMA (1, 1, 1) x (2, 1, 0, 1)12 : AIC Calculated =1360.3998207889665
# ARIMA (1, 1, 1) x (2, 1, 1, 1)12 : AIC Calculated =1360.870160754079
# ARIMA (1, 1, 1) x (2, 1, 2, 1)12 : AIC Calculated =1340.7629032286518
# ARIMA (1, 1, 1) x (2, 2, 0, 1)12 : AIC Calculated =1357.2397655112034
# ARIMA (1, 1, 1) x (2, 2, 1, 1)12 : AIC Calculated =1357.635477120767
# ARIMA (1, 1, 1) x (2, 2, 2, 1)12 : AIC Calculated =1331.9846072622076
# ARIMA (1, 1, 2) x (0, 0, 0, 1)12 : AIC Calculated =1378.921185707355
# ARIMA (1, 1, 2) x (0, 0, 1, 1)12 : AIC Calculated =1361.2859263679056
# ARIMA (1, 1, 2) x (0, 0, 2, 1)12 : AIC Calculated =1343.0050514379275
# ARIMA (1, 1, 2) x (0, 1, 0, 1)12 : AIC Calculated =1358.7302993878952
# ARIMA (1, 1, 2) x (0, 1, 1, 1)12 : AIC Calculated =1344.6150859737527
# ARIMA (1, 1, 2) x (0, 1, 2, 1)12 : AIC Calculated =1328.4456274985032
# ARIMA (1, 1, 2) x (0, 2, 0, 1)12 : AIC Calculated =1377.8903626526646
# ARIMA (1, 1, 2) x (0, 2, 1, 1)12 : AIC Calculated =1338.448732548956
# ARIMA (1, 1, 2) x (0, 2, 2, 1)12 : AIC Calculated =1326.3310189412693
# ARIMA (1, 1, 2) x (1, 0, 0, 1)12 : AIC Calculated =1378.5124815144527
# ARIMA (1, 1, 2) x (1, 0, 1, 1)12 : AIC Calculated =1362.5735292681672
# ARIMA (1, 1, 2) x (1, 0, 2, 1)12 : AIC Calculated =1355.6793948328616
# ARIMA (1, 1, 2) x (1, 1, 0, 1)12 : AIC Calculated =1360.6958393426326
# ARIMA (1, 1, 2) x (1, 1, 1, 1)12 : AIC Calculated =1346.4645364440705
# ARIMA (1, 1, 2) x (1, 1, 2, 1)12 : AIC Calculated =1333.334167983387
# ARIMA (1, 1, 2) x (1, 2, 0, 1)12 : AIC Calculated =1379.8903269190675
# ARIMA (1, 1, 2) x (1, 2, 1, 1)12 : AIC Calculated =1339.0595706121444
# ARIMA (1, 1, 2) x (1, 2, 2, 1)12 : AIC Calculated =1328.0642271662002
# ARIMA (1, 1, 2) x (2, 0, 0, 1)12 : AIC Calculated =1371.9391755229028
# ARIMA (1, 1, 2) x (2, 0, 1, 1)12 : AIC Calculated =1369.1724422904404
# ARIMA (1, 1, 2) x (2, 0, 2, 1)12 : AIC Calculated =1342.7963444679963
# ARIMA (1, 1, 2) x (2, 1, 0, 1)12 : AIC Calculated =1352.6660167252053
# ARIMA (1, 1, 2) x (2, 1, 1, 1)12 : AIC Calculated =1340.7502809504535
# ARIMA (1, 1, 2) x (2, 1, 2, 1)12 : AIC Calculated =1327.4081000325268
# ARIMA (1, 1, 2) x (2, 2, 0, 1)12 : AIC Calculated =1357.631581664919
# ARIMA (1, 1, 2) x (2, 2, 1, 1)12 : AIC Calculated =1331.9780816801676
# ARIMA (1, 1, 2) x (2, 2, 2, 1)12 : AIC Calculated =1314.9230821444746
# ARIMA (1, 2, 0) x (0, 0, 0, 1)12 : AIC Calculated =1431.6399390312426
# ARIMA (1, 2, 0) x (0, 0, 1, 1)12 : AIC Calculated =1402.6331437902077
# ARIMA (1, 2, 0) x (0, 0, 2, 1)12 : AIC Calculated =1358.7302993897908
# ARIMA (1, 2, 0) x (0, 1, 0, 1)12 : AIC Calculated =1469.3717211322419
# ARIMA (1, 2, 0) x (0, 1, 1, 1)12 : AIC Calculated =1424.2221588493514
# ARIMA (1, 2, 0) x (0, 1, 2, 1)12 : AIC Calculated =1377.8903627464583
# ARIMA (1, 2, 0) x (0, 2, 0, 1)12 : AIC Calculated =1511.3763172104393
# ARIMA (1, 2, 0) x (0, 2, 1, 1)12 : AIC Calculated =1461.7792312379936
# ARIMA (1, 2, 0) x (0, 2, 2, 1)12 : AIC Calculated =1448.0777124932622
# ARIMA (1, 2, 0) x (1, 0, 0, 1)12 : AIC Calculated =1419.0982880007552
# ARIMA (1, 2, 0) x (1, 0, 1, 1)12 : AIC Calculated =1404.4519659933524
# ARIMA (1, 2, 0) x (1, 0, 2, 1)12 : AIC Calculated =1360.6958393420782
# ARIMA (1, 2, 0) x (1, 1, 0, 1)12 : AIC Calculated =1454.757366118591
# ARIMA (1, 2, 0) x (1, 1, 1, 1)12 : AIC Calculated =1423.07462976377
# ARIMA (1, 2, 0) x (1, 1, 2, 1)12 : AIC Calculated =1379.8903269734244
# ARIMA (1, 2, 0) x (1, 2, 0, 1)12 : AIC Calculated =1496.9169524025085
# ARIMA (1, 2, 0) x (1, 2, 1, 1)12 : AIC Calculated =1463.7792272756972
# ARIMA (1, 2, 0) x (1, 2, 2, 1)12 : AIC Calculated =1446.5142119497484
# ARIMA (1, 2, 0) x (2, 0, 0, 1)12 : AIC Calculated =1360.9761475563473
# ARIMA (1, 2, 0) x (2, 0, 1, 1)12 : AIC Calculated =1360.3998208178043
# ARIMA (1, 2, 0) x (2, 0, 2, 1)12 : AIC Calculated =1352.6675454436088
# ARIMA (1, 2, 0) x (2, 1, 0, 1)12 : AIC Calculated =1380.4963599120706
# ARIMA (1, 2, 0) x (2, 1, 1, 1)12 : AIC Calculated =1357.2397655077893
# ARIMA (1, 2, 0) x (2, 1, 2, 1)12 : AIC Calculated =1370.5004392117448
# ARIMA (1, 2, 0) x (2, 2, 0, 1)12 : AIC Calculated =1416.4231588675152
# ARIMA (1, 2, 0) x (2, 2, 1, 1)12 : AIC Calculated =1417.30746881123
# ARIMA (1, 2, 0) x (2, 2, 2, 1)12 : AIC Calculated =1418.963518998341
# ARIMA (1, 2, 1) x (0, 0, 0, 1)12 : AIC Calculated =1402.6331437263896
# ARIMA (1, 2, 1) x (0, 0, 1, 1)12 : AIC Calculated =1358.730299402446
# ARIMA (1, 2, 1) x (0, 0, 2, 1)12 : AIC Calculated =1344.615085962102
# ARIMA (1, 2, 1) x (0, 1, 0, 1)12 : AIC Calculated =1424.2221587323347
# ARIMA (1, 2, 1) x (0, 1, 1, 1)12 : AIC Calculated =1377.8903626978015
# ARIMA (1, 2, 1) x (0, 1, 2, 1)12 : AIC Calculated =1338.5263714074486
# ARIMA (1, 2, 1) x (0, 2, 0, 1)12 : AIC Calculated =1461.8462249947397
# ARIMA (1, 2, 1) x (0, 2, 1, 1)12 : AIC Calculated =1423.6350750817726
# ARIMA (1, 2, 1) x (0, 2, 2, 1)12 : AIC Calculated =1366.126800645994
# ARIMA (1, 2, 1) x (1, 0, 0, 1)12 : AIC Calculated =1404.4519659833209
# ARIMA (1, 2, 1) x (1, 0, 1, 1)12 : AIC Calculated =1386.6267096897175
# ARIMA (1, 2, 1) x (1, 0, 2, 1)12 : AIC Calculated =1346.4645362541091
# ARIMA (1, 2, 1) x (1, 1, 0, 1)12 : AIC Calculated =1423.0746297334354
# ARIMA (1, 2, 1) x (1, 1, 1, 1)12 : AIC Calculated =1399.9810215797881
# ARIMA (1, 2, 1) x (1, 1, 2, 1)12 : AIC Calculated =1339.0595705591768
# ARIMA (1, 2, 1) x (1, 2, 0, 1)12 : AIC Calculated =1463.8460927863644
# ARIMA (1, 2, 1) x (1, 2, 1, 1)12 : AIC Calculated =1418.2974569311066
# ARIMA (1, 2, 1) x (1, 2, 2, 1)12 : AIC Calculated =1367.9039657287121
# ARIMA (1, 2, 1) x (2, 0, 0, 1)12 : AIC Calculated =1360.3998207889665
# ARIMA (1, 2, 1) x (2, 0, 1, 1)12 : AIC Calculated =1360.870160754079
# ARIMA (1, 2, 1) x (2, 0, 2, 1)12 : AIC Calculated =1340.7629032286518
# ARIMA (1, 2, 1) x (2, 1, 0, 1)12 : AIC Calculated =1357.2397655112034
# ARIMA (1, 2, 1) x (2, 1, 1, 1)12 : AIC Calculated =1357.635477120767
# ARIMA (1, 2, 1) x (2, 1, 2, 1)12 : AIC Calculated =1331.9846072622076
# ARIMA (1, 2, 1) x (2, 2, 0, 1)12 : AIC Calculated =1417.307468504772
# ARIMA (1, 2, 1) x (2, 2, 1, 1)12 : AIC Calculated =1418.963519067069
# ARIMA (1, 2, 1) x (2, 2, 2, 1)12 : AIC Calculated =1365.4785195700904
# ARIMA (1, 2, 2) x (0, 0, 0, 1)12 : AIC Calculated =1358.7302993878952
# ARIMA (1, 2, 2) x (0, 0, 1, 1)12 : AIC Calculated =1344.6150859737527
# ARIMA (1, 2, 2) x (0, 0, 2, 1)12 : AIC Calculated =1328.4456274985032
# ARIMA (1, 2, 2) x (0, 1, 0, 1)12 : AIC Calculated =1377.8903626526646
# ARIMA (1, 2, 2) x (0, 1, 1, 1)12 : AIC Calculated =1338.448732548956
# ARIMA (1, 2, 2) x (0, 1, 2, 1)12 : AIC Calculated =1326.3310189412693
# ARIMA (1, 2, 2) x (0, 2, 0, 1)12 : AIC Calculated =1448.0060882581624
# ARIMA (1, 2, 2) x (0, 2, 1, 1)12 : AIC Calculated =1366.1268007203832
# ARIMA (1, 2, 2) x (0, 2, 2, 1)12 : AIC Calculated =1354.5418050712562
# ARIMA (1, 2, 2) x (1, 0, 0, 1)12 : AIC Calculated =1360.6958393426326
# ARIMA (1, 2, 2) x (1, 0, 1, 1)12 : AIC Calculated =1346.4645364440705
# ARIMA (1, 2, 2) x (1, 0, 2, 1)12 : AIC Calculated =1333.334167983387
# ARIMA (1, 2, 2) x (1, 1, 0, 1)12 : AIC Calculated =1379.8903269190675
# ARIMA (1, 2, 2) x (1, 1, 1, 1)12 : AIC Calculated =1339.0595706121444
# ARIMA (1, 2, 2) x (1, 1, 2, 1)12 : AIC Calculated =1328.0642271662002
# ARIMA (1, 2, 2) x (1, 2, 0, 1)12 : AIC Calculated =1446.4972421129253
# ARIMA (1, 2, 2) x (1, 2, 1, 1)12 : AIC Calculated =1367.903965707766
# ARIMA (1, 2, 2) x (1, 2, 2, 1)12 : AIC Calculated =1328.257311917848
# ARIMA (1, 2, 2) x (2, 0, 0, 1)12 : AIC Calculated =1352.6660167252053
# ARIMA (1, 2, 2) x (2, 0, 1, 1)12 : AIC Calculated =1340.7502809504535
# ARIMA (1, 2, 2) x (2, 0, 2, 1)12 : AIC Calculated =1327.4081000325268
# ARIMA (1, 2, 2) x (2, 1, 0, 1)12 : AIC Calculated =1357.631581664919
# ARIMA (1, 2, 2) x (2, 1, 1, 1)12 : AIC Calculated =1331.9780816801676
# ARIMA (1, 2, 2) x (2, 1, 2, 1)12 : AIC Calculated =1314.9230821444746
# ARIMA (1, 2, 2) x (2, 2, 0, 1)12 : AIC Calculated =1418.9679293691522
# ARIMA (1, 2, 2) x (2, 2, 1, 1)12 : AIC Calculated =1372.0488503674383
# ARIMA (1, 2, 2) x (2, 2, 2, 1)12 : AIC Calculated =1358.215231587446
# ARIMA (2, 0, 0) x (0, 0, 0, 1)12 : AIC Calculated =1436.9160497678513
# ARIMA (2, 0, 0) x (0, 0, 1, 1)12 : AIC Calculated =1414.6943030121893
# ARIMA (2, 0, 0) x (0, 0, 2, 1)12 : AIC Calculated =1385.9878609449834
# ARIMA (2, 0, 0) x (0, 1, 0, 1)12 : AIC Calculated =1414.4924412562132
# ARIMA (2, 0, 0) x (0, 1, 1, 1)12 : AIC Calculated =1398.1983848266448
# ARIMA (2, 0, 0) x (0, 1, 2, 1)12 : AIC Calculated =1380.4840874234612
# ARIMA (2, 0, 0) x (0, 2, 0, 1)12 : AIC Calculated =1373.0297873463624
# ARIMA (2, 0, 0) x (0, 2, 1, 1)12 : AIC Calculated =1374.7187240476467
# ARIMA (2, 0, 0) x (0, 2, 2, 1)12 : AIC Calculated =1358.7924704135532
# ARIMA (2, 0, 0) x (1, 0, 0, 1)12 : AIC Calculated =1399.6549891356399
# ARIMA (2, 0, 0) x (1, 0, 1, 1)12 : AIC Calculated =1396.91647608339
# ARIMA (2, 0, 0) x (1, 0, 2, 1)12 : AIC Calculated =1392.3809198336262
# ARIMA (2, 0, 0) x (1, 1, 0, 1)12 : AIC Calculated =1372.6164383360688
# ARIMA (2, 0, 0) x (1, 1, 1, 1)12 : AIC Calculated =1374.4488286409478
# ARIMA (2, 0, 0) x (1, 1, 2, 1)12 : AIC Calculated =1371.9391755204645
# ARIMA (2, 0, 0) x (1, 2, 0, 1)12 : AIC Calculated =1360.976330171272
# ARIMA (2, 0, 0) x (1, 2, 1, 1)12 : AIC Calculated =1360.3998208274356
# ARIMA (2, 0, 0) x (1, 2, 2, 1)12 : AIC Calculated =1352.6660166616632
# ARIMA (2, 0, 0) x (2, 0, 0, 1)12 : AIC Calculated =1421.84582580176
# ARIMA (2, 0, 0) x (2, 0, 1, 1)12 : AIC Calculated =1378.1309780672843
# ARIMA (2, 0, 0) x (2, 0, 2, 1)12 : AIC Calculated =1379.4292733840202
# ARIMA (2, 0, 0) x (2, 1, 0, 1)12 : AIC Calculated =1375.4234806706654
# ARIMA (2, 0, 0) x (2, 1, 1, 1)12 : AIC Calculated =1359.8744178434808
# ARIMA (2, 0, 0) x (2, 1, 2, 1)12 : AIC Calculated =1355.3804041620335
# ARIMA (2, 0, 0) x (2, 2, 0, 1)12 : AIC Calculated =1344.4123572235146
# ARIMA (2, 0, 0) x (2, 2, 1, 1)12 : AIC Calculated =1335.8876113590106
# ARIMA (2, 0, 0) x (2, 2, 2, 1)12 : AIC Calculated =1337.3795120859688
# ARIMA (2, 0, 1) x (0, 0, 0, 1)12 : AIC Calculated =1409.4240342378137
# ARIMA (2, 0, 1) x (0, 0, 1, 1)12 : AIC Calculated =1388.233532532927
# ARIMA (2, 0, 1) x (0, 0, 2, 1)12 : AIC Calculated =1386.5588589043487
# ARIMA (2, 0, 1) x (0, 1, 0, 1)12 : AIC Calculated =1398.1734972919899
# ARIMA (2, 0, 1) x (0, 1, 1, 1)12 : AIC Calculated =1383.1228023565654
# ARIMA (2, 0, 1) x (0, 1, 2, 1)12 : AIC Calculated =1368.4860941068277
# ARIMA (2, 0, 1) x (0, 2, 0, 1)12 : AIC Calculated =1374.7203100517465
# ARIMA (2, 0, 1) x (0, 2, 1, 1)12 : AIC Calculated =1358.7924699458179
# ARIMA (2, 0, 1) x (0, 2, 2, 1)12 : AIC Calculated =1338.9332994556848
# ARIMA (2, 0, 1) x (1, 0, 0, 1)12 : AIC Calculated =1391.121280343834
# ARIMA (2, 0, 1) x (1, 0, 1, 1)12 : AIC Calculated =1388.7420865719555
# ARIMA (2, 0, 1) x (1, 0, 2, 1)12 : AIC Calculated =1374.1567092481005
# ARIMA (2, 0, 1) x (1, 1, 0, 1)12 : AIC Calculated =1385.0435902611791
# ARIMA (2, 0, 1) x (1, 1, 1, 1)12 : AIC Calculated =1385.9843469688644
# ARIMA (2, 0, 1) x (1, 1, 2, 1)12 : AIC Calculated =1369.329448886373
# ARIMA (2, 0, 1) x (1, 2, 0, 1)12 : AIC Calculated =1360.409945898596
# ARIMA (2, 0, 1) x (1, 2, 1, 1)12 : AIC Calculated =1352.667545469562
# ARIMA (2, 0, 1) x (1, 2, 2, 1)12 : AIC Calculated =1340.7530983831077
# ARIMA (2, 0, 1) x (2, 0, 0, 1)12 : AIC Calculated =1370.0978660201683
# ARIMA (2, 0, 1) x (2, 0, 1, 1)12 : AIC Calculated =1370.9074256864228
# ARIMA (2, 0, 1) x (2, 0, 2, 1)12 : AIC Calculated =1373.6293078543445
# ARIMA (2, 0, 1) x (2, 1, 0, 1)12 : AIC Calculated =1359.5715671701207
# ARIMA (2, 0, 1) x (2, 1, 1, 1)12 : AIC Calculated =1372.9413006568006
# ARIMA (2, 0, 1) x (2, 1, 2, 1)12 : AIC Calculated =1372.3613581887594
# ARIMA (2, 0, 1) x (2, 2, 0, 1)12 : AIC Calculated =1335.8876113278504
# ARIMA (2, 0, 1) x (2, 2, 1, 1)12 : AIC Calculated =1347.4546894933596
# ARIMA (2, 0, 1) x (2, 2, 2, 1)12 : AIC Calculated =1338.9549810370304
# ARIMA (2, 0, 2) x (0, 0, 0, 1)12 : AIC Calculated =1382.6042904126741
# ARIMA (2, 0, 2) x (0, 0, 1, 1)12 : AIC Calculated =1383.5253903296639
# ARIMA (2, 0, 2) x (0, 0, 2, 1)12 : AIC Calculated =1367.73539171807
# ARIMA (2, 0, 2) x (0, 1, 0, 1)12 : AIC Calculated =1378.5124814892647
# ARIMA (2, 0, 2) x (0, 1, 1, 1)12 : AIC Calculated =1362.960767469376
# ARIMA (2, 0, 2) x (0, 1, 2, 1)12 : AIC Calculated =1345.9926407771359
# ARIMA (2, 0, 2) x (0, 2, 0, 1)12 : AIC Calculated =1358.799234680279
# ARIMA (2, 0, 2) x (0, 2, 1, 1)12 : AIC Calculated =1338.9332891940242
# ARIMA (2, 0, 2) x (0, 2, 2, 1)12 : AIC Calculated =1327.4412816831525
# ARIMA (2, 0, 2) x (1, 0, 0, 1)12 : AIC Calculated =1383.258336607271
# ARIMA (2, 0, 2) x (1, 0, 1, 1)12 : AIC Calculated =1376.8546735063371
# ARIMA (2, 0, 2) x (1, 0, 2, 1)12 : AIC Calculated =1355.5052518441776
# ARIMA (2, 0, 2) x (1, 1, 0, 1)12 : AIC Calculated =1371.9391755255515
# ARIMA (2, 0, 2) x (1, 1, 1, 1)12 : AIC Calculated =1364.4344288119535
# ARIMA (2, 0, 2) x (1, 1, 2, 1)12 : AIC Calculated =1342.7156810189842
# ARIMA (2, 0, 2) x (1, 2, 0, 1)12 : AIC Calculated =1352.8531686581794
# ARIMA (2, 0, 2) x (1, 2, 1, 1)12 : AIC Calculated =1340.8393659204733
# ARIMA (2, 0, 2) x (1, 2, 2, 1)12 : AIC Calculated =1330.2959535367374
# ARIMA (2, 0, 2) x (2, 0, 0, 1)12 : AIC Calculated =1370.4180689953394
# ARIMA (2, 0, 2) x (2, 0, 1, 1)12 : AIC Calculated =1371.3675523215084
# ARIMA (2, 0, 2) x (2, 0, 2, 1)12 : AIC Calculated =1365.3115992008477
# ARIMA (2, 0, 2) x (2, 1, 0, 1)12 : AIC Calculated =1355.3804051305053
# ARIMA (2, 0, 2) x (2, 1, 1, 1)12 : AIC Calculated =1372.7272474534127
# ARIMA (2, 0, 2) x (2, 1, 2, 1)12 : AIC Calculated =1345.7116533365947
# ARIMA (2, 0, 2) x (2, 2, 0, 1)12 : AIC Calculated =1337.3795177311918
# ARIMA (2, 0, 2) x (2, 2, 1, 1)12 : AIC Calculated =1338.867110883902
# ARIMA (2, 0, 2) x (2, 2, 2, 1)12 : AIC Calculated =1328.9130143025961
# ARIMA (2, 1, 0) x (0, 0, 0, 1)12 : AIC Calculated =1414.4924412562132
# ARIMA (2, 1, 0) x (0, 0, 1, 1)12 : AIC Calculated =1398.1983848266448
# ARIMA (2, 1, 0) x (0, 0, 2, 1)12 : AIC Calculated =1380.4840874234612
# ARIMA (2, 1, 0) x (0, 1, 0, 1)12 : AIC Calculated =1373.0297873463624
# ARIMA (2, 1, 0) x (0, 1, 1, 1)12 : AIC Calculated =1374.7187240476467
# ARIMA (2, 1, 0) x (0, 1, 2, 1)12 : AIC Calculated =1358.7924704135532
# ARIMA (2, 1, 0) x (0, 2, 0, 1)12 : AIC Calculated =1398.6642901428568
# ARIMA (2, 1, 0) x (0, 2, 1, 1)12 : AIC Calculated =1400.346162747157
# ARIMA (2, 1, 0) x (0, 2, 2, 1)12 : AIC Calculated =1371.1362621995954
# ARIMA (2, 1, 0) x (1, 0, 0, 1)12 : AIC Calculated =1372.6164383360688
# ARIMA (2, 1, 0) x (1, 0, 1, 1)12 : AIC Calculated =1374.4488286409478
# ARIMA (2, 1, 0) x (1, 0, 2, 1)12 : AIC Calculated =1371.9391755204645
# ARIMA (2, 1, 0) x (1, 1, 0, 1)12 : AIC Calculated =1360.976330171272
# ARIMA (2, 1, 0) x (1, 1, 1, 1)12 : AIC Calculated =1360.3998208274356
# ARIMA (2, 1, 0) x (1, 1, 2, 1)12 : AIC Calculated =1352.6660166616632
# ARIMA (2, 1, 0) x (1, 2, 0, 1)12 : AIC Calculated =1380.49635993877
# ARIMA (2, 1, 0) x (1, 2, 1, 1)12 : AIC Calculated =1357.2397654896747
# ARIMA (2, 1, 0) x (1, 2, 2, 1)12 : AIC Calculated =1357.6320151931197
# ARIMA (2, 1, 0) x (2, 0, 0, 1)12 : AIC Calculated =1375.4234806706654
# ARIMA (2, 1, 0) x (2, 0, 1, 1)12 : AIC Calculated =1359.8744178434808
# ARIMA (2, 1, 0) x (2, 0, 2, 1)12 : AIC Calculated =1355.3804041620335
# ARIMA (2, 1, 0) x (2, 1, 0, 1)12 : AIC Calculated =1344.4123572235146
# ARIMA (2, 1, 0) x (2, 1, 1, 1)12 : AIC Calculated =1335.8876113590106
# ARIMA (2, 1, 0) x (2, 1, 2, 1)12 : AIC Calculated =1337.3795120859688
# ARIMA (2, 1, 0) x (2, 2, 0, 1)12 : AIC Calculated =1368.2525447299165
# ARIMA (2, 1, 0) x (2, 2, 1, 1)12 : AIC Calculated =1344.5875720012455
# ARIMA (2, 1, 0) x (2, 2, 2, 1)12 : AIC Calculated =1365.6086051032273
# ARIMA (2, 1, 1) x (0, 0, 0, 1)12 : AIC Calculated =1398.1734972919899
# ARIMA (2, 1, 1) x (0, 0, 1, 1)12 : AIC Calculated =1383.1228023565654
# ARIMA (2, 1, 1) x (0, 0, 2, 1)12 : AIC Calculated =1368.4860941068277
# ARIMA (2, 1, 1) x (0, 1, 0, 1)12 : AIC Calculated =1374.7203100517465
# ARIMA (2, 1, 1) x (0, 1, 1, 1)12 : AIC Calculated =1358.7924699458179
# ARIMA (2, 1, 1) x (0, 1, 2, 1)12 : AIC Calculated =1338.9332994556848
# ARIMA (2, 1, 1) x (0, 2, 0, 1)12 : AIC Calculated =1400.3459199709473
# ARIMA (2, 1, 1) x (0, 2, 1, 1)12 : AIC Calculated =1381.9370632002242
# ARIMA (2, 1, 1) x (0, 2, 2, 1)12 : AIC Calculated =1337.8588254130639
# ARIMA (2, 1, 1) x (1, 0, 0, 1)12 : AIC Calculated =1385.0435902611791
# ARIMA (2, 1, 1) x (1, 0, 1, 1)12 : AIC Calculated =1385.9843469688644
# ARIMA (2, 1, 1) x (1, 0, 2, 1)12 : AIC Calculated =1369.329448886373
# ARIMA (2, 1, 1) x (1, 1, 0, 1)12 : AIC Calculated =1360.409945898596
# ARIMA (2, 1, 1) x (1, 1, 1, 1)12 : AIC Calculated =1352.667545469562
# ARIMA (2, 1, 1) x (1, 1, 2, 1)12 : AIC Calculated =1340.7530983831077
# ARIMA (2, 1, 1) x (1, 2, 0, 1)12 : AIC Calculated =1357.2397654952115
# ARIMA (2, 1, 1) x (1, 2, 1, 1)12 : AIC Calculated =1357.6315810225606
# ARIMA (2, 1, 1) x (1, 2, 2, 1)12 : AIC Calculated =1331.9780815488025
# ARIMA (2, 1, 1) x (2, 0, 0, 1)12 : AIC Calculated =1359.5715671701207
# ARIMA (2, 1, 1) x (2, 0, 1, 1)12 : AIC Calculated =1372.9413006568006
# ARIMA (2, 1, 1) x (2, 0, 2, 1)12 : AIC Calculated =1372.3613581887594
# ARIMA (2, 1, 1) x (2, 1, 0, 1)12 : AIC Calculated =1335.8876113278504
# ARIMA (2, 1, 1) x (2, 1, 1, 1)12 : AIC Calculated =1347.4546894933596
# ARIMA (2, 1, 1) x (2, 1, 2, 1)12 : AIC Calculated =1338.9549810370304
# ARIMA (2, 1, 1) x (2, 2, 0, 1)12 : AIC Calculated =1344.587571985698
# ARIMA (2, 1, 1) x (2, 2, 1, 1)12 : AIC Calculated =1370.9507139560135
# ARIMA (2, 1, 1) x (2, 2, 2, 1)12 : AIC Calculated =1366.247520152495
# ARIMA (2, 1, 2) x (0, 0, 0, 1)12 : AIC Calculated =1378.5124814892647
# ARIMA (2, 1, 2) x (0, 0, 1, 1)12 : AIC Calculated =1362.960767469376
# ARIMA (2, 1, 2) x (0, 0, 2, 1)12 : AIC Calculated =1345.9926407771359
# ARIMA (2, 1, 2) x (0, 1, 0, 1)12 : AIC Calculated =1358.799234680279
# ARIMA (2, 1, 2) x (0, 1, 1, 1)12 : AIC Calculated =1338.9332891940242
# ARIMA (2, 1, 2) x (0, 1, 2, 1)12 : AIC Calculated =1327.4412816831525
# ARIMA (2, 1, 2) x (0, 2, 0, 1)12 : AIC Calculated =1371.1457095541882
# ARIMA (2, 1, 2) x (0, 2, 1, 1)12 : AIC Calculated =1364.1103410476685
# ARIMA (2, 1, 2) x (0, 2, 2, 1)12 : AIC Calculated =1315.6176859906361
# ARIMA (2, 1, 2) x (1, 0, 0, 1)12 : AIC Calculated =1371.9391755255515
# ARIMA (2, 1, 2) x (1, 0, 1, 1)12 : AIC Calculated =1364.4344288119535
# ARIMA (2, 1, 2) x (1, 0, 2, 1)12 : AIC Calculated =1342.7156810189842
# ARIMA (2, 1, 2) x (1, 1, 0, 1)12 : AIC Calculated =1352.8531686581794
# ARIMA (2, 1, 2) x (1, 1, 1, 1)12 : AIC Calculated =1340.8393659204733
# ARIMA (2, 1, 2) x (1, 1, 2, 1)12 : AIC Calculated =1330.2959535367374
# ARIMA (2, 1, 2) x (1, 2, 0, 1)12 : AIC Calculated =1357.6315811773306
# ARIMA (2, 1, 2) x (1, 2, 1, 1)12 : AIC Calculated =1331.978081582629
# ARIMA (2, 1, 2) x (1, 2, 2, 1)12 : AIC Calculated =1315.0939363042542
# ARIMA (2, 1, 2) x (2, 0, 0, 1)12 : AIC Calculated =1355.3804051305053
# ARIMA (2, 1, 2) x (2, 0, 1, 1)12 : AIC Calculated =1372.7272474534127
# ARIMA (2, 1, 2) x (2, 0, 2, 1)12 : AIC Calculated =1345.7116533365947
# ARIMA (2, 1, 2) x (2, 1, 0, 1)12 : AIC Calculated =1337.3795177311918
# ARIMA (2, 1, 2) x (2, 1, 1, 1)12 : AIC Calculated =1338.867110883902
# ARIMA (2, 1, 2) x (2, 1, 2, 1)12 : AIC Calculated =1328.9130143025961
# ARIMA (2, 1, 2) x (2, 2, 0, 1)12 : AIC Calculated =1365.6086050409822
# ARIMA (2, 1, 2) x (2, 2, 1, 1)12 : AIC Calculated =1337.2919413252794
# ARIMA (2, 1, 2) x (2, 2, 2, 1)12 : AIC Calculated =1317.6250976904146
# ARIMA (2, 2, 0) x (0, 0, 0, 1)12 : AIC Calculated =1373.0297873463624
# ARIMA (2, 2, 0) x (0, 0, 1, 1)12 : AIC Calculated =1374.7187240476467
# ARIMA (2, 2, 0) x (0, 0, 2, 1)12 : AIC Calculated =1358.7924704135532
# ARIMA (2, 2, 0) x (0, 1, 0, 1)12 : AIC Calculated =1398.6642901428568
# ARIMA (2, 2, 0) x (0, 1, 1, 1)12 : AIC Calculated =1400.346162747157
# ARIMA (2, 2, 0) x (0, 1, 2, 1)12 : AIC Calculated =1371.1362621995954
# ARIMA (2, 2, 0) x (0, 2, 0, 1)12 : AIC Calculated =1449.7549728752679
# ARIMA (2, 2, 0) x (0, 2, 1, 1)12 : AIC Calculated =1450.9059815516773
# ARIMA (2, 2, 0) x (0, 2, 2, 1)12 : AIC Calculated =1419.2726153935876
# ARIMA (2, 2, 0) x (1, 0, 0, 1)12 : AIC Calculated =1360.976330171272
# ARIMA (2, 2, 0) x (1, 0, 1, 1)12 : AIC Calculated =1360.3998208274356
# ARIMA (2, 2, 0) x (1, 0, 2, 1)12 : AIC Calculated =1352.6660166616632
# ARIMA (2, 2, 0) x (1, 1, 0, 1)12 : AIC Calculated =1380.49635993877
# ARIMA (2, 2, 0) x (1, 1, 1, 1)12 : AIC Calculated =1357.2397654896747
# ARIMA (2, 2, 0) x (1, 1, 2, 1)12 : AIC Calculated =1357.6320151931197
# ARIMA (2, 2, 0) x (1, 2, 0, 1)12 : AIC Calculated =1416.4231588579537
# ARIMA (2, 2, 0) x (1, 2, 1, 1)12 : AIC Calculated =1417.3074684940416
# ARIMA (2, 2, 0) x (1, 2, 2, 1)12 : AIC Calculated =1418.9635190173497
# ARIMA (2, 2, 0) x (2, 0, 0, 1)12 : AIC Calculated =1344.4123572235146
# ARIMA (2, 2, 0) x (2, 0, 1, 1)12 : AIC Calculated =1335.8876113590106
# ARIMA (2, 2, 0) x (2, 0, 2, 1)12 : AIC Calculated =1337.3795120859688
# ARIMA (2, 2, 0) x (2, 1, 0, 1)12 : AIC Calculated =1368.2525447299165
# ARIMA (2, 2, 0) x (2, 1, 1, 1)12 : AIC Calculated =1344.5875720012455
# ARIMA (2, 2, 0) x (2, 1, 2, 1)12 : AIC Calculated =1365.6086051032273
# ARIMA (2, 2, 0) x (2, 2, 0, 1)12 : AIC Calculated =1398.7135485121592
# ARIMA (2, 2, 0) x (2, 2, 1, 1)12 : AIC Calculated =1389.559348454153
# ARIMA (2, 2, 0) x (2, 2, 2, 1)12 : AIC Calculated =1368.3025666185088
# ARIMA (2, 2, 1) x (0, 0, 0, 1)12 : AIC Calculated =1374.7203100517465
# ARIMA (2, 2, 1) x (0, 0, 1, 1)12 : AIC Calculated =1358.7924699458179
# ARIMA (2, 2, 1) x (0, 0, 2, 1)12 : AIC Calculated =1338.9332994556848
# ARIMA (2, 2, 1) x (0, 1, 0, 1)12 : AIC Calculated =1400.3459199709473
# ARIMA (2, 2, 1) x (0, 1, 1, 1)12 : AIC Calculated =1381.9370632002242
# ARIMA (2, 2, 1) x (0, 1, 2, 1)12 : AIC Calculated =1337.8588254130639
# ARIMA (2, 2, 1) x (0, 2, 0, 1)12 : AIC Calculated =1442.5379687843374
# ARIMA (2, 2, 1) x (0, 2, 1, 1)12 : AIC Calculated =1419.2726146743282
# ARIMA (2, 2, 1) x (0, 2, 2, 1)12 : AIC Calculated =1366.5724065581762
# ARIMA (2, 2, 1) x (1, 0, 0, 1)12 : AIC Calculated =1360.409945898596
# ARIMA (2, 2, 1) x (1, 0, 1, 1)12 : AIC Calculated =1352.667545469562
# ARIMA (2, 2, 1) x (1, 0, 2, 1)12 : AIC Calculated =1340.7530983831077
# ARIMA (2, 2, 1) x (1, 1, 0, 1)12 : AIC Calculated =1357.2397654952115
# ARIMA (2, 2, 1) x (1, 1, 1, 1)12 : AIC Calculated =1357.6315810225606
# ARIMA (2, 2, 1) x (1, 1, 2, 1)12 : AIC Calculated =1331.9780815488025
# ARIMA (2, 2, 1) x (1, 2, 0, 1)12 : AIC Calculated =1417.3641330919809
# ARIMA (2, 2, 1) x (1, 2, 1, 1)12 : AIC Calculated =1419.05924232999
# ARIMA (2, 2, 1) x (1, 2, 2, 1)12 : AIC Calculated =1355.1923690437281
# ARIMA (2, 2, 1) x (2, 0, 0, 1)12 : AIC Calculated =1335.8876113278504
# ARIMA (2, 2, 1) x (2, 0, 1, 1)12 : AIC Calculated =1347.4546894933596
# ARIMA (2, 2, 1) x (2, 0, 2, 1)12 : AIC Calculated =1338.9549810370304
# ARIMA (2, 2, 1) x (2, 1, 0, 1)12 : AIC Calculated =1344.587571985698
# ARIMA (2, 2, 1) x (2, 1, 1, 1)12 : AIC Calculated =1370.9507139560135
# ARIMA (2, 2, 1) x (2, 1, 2, 1)12 : AIC Calculated =1366.247520152495
# ARIMA (2, 2, 1) x (2, 2, 0, 1)12 : AIC Calculated =1388.0782808019298
# ARIMA (2, 2, 1) x (2, 2, 1, 1)12 : AIC Calculated =1357.0797347362618
# ARIMA (2, 2, 1) x (2, 2, 2, 1)12 : AIC Calculated =1359.2653068178256
# ARIMA (2, 2, 2) x (0, 0, 0, 1)12 : AIC Calculated =1358.799234680279
# ARIMA (2, 2, 2) x (0, 0, 1, 1)12 : AIC Calculated =1338.9332891940242
# ARIMA (2, 2, 2) x (0, 0, 2, 1)12 : AIC Calculated =1327.4412816831525
# ARIMA (2, 2, 2) x (0, 1, 0, 1)12 : AIC Calculated =1371.1457095541882
# ARIMA (2, 2, 2) x (0, 1, 1, 1)12 : AIC Calculated =1364.1103410476685
# ARIMA (2, 2, 2) x (0, 1, 2, 1)12 : AIC Calculated =1315.6176859906361
# ARIMA (2, 2, 2) x (0, 2, 0, 1)12 : AIC Calculated =1419.2140743111663
# ARIMA (2, 2, 2) x (0, 2, 1, 1)12 : AIC Calculated =1358.2689556582916
# ARIMA (2, 2, 2) x (0, 2, 2, 1)12 : AIC Calculated =1326.952775021999
# ARIMA (2, 2, 2) x (1, 0, 0, 1)12 : AIC Calculated =1352.8531686581794
# ARIMA (2, 2, 2) x (1, 0, 1, 1)12 : AIC Calculated =1340.8393659204733
# ARIMA (2, 2, 2) x (1, 0, 2, 1)12 : AIC Calculated =1330.2959535367374
# ARIMA (2, 2, 2) x (1, 1, 0, 1)12 : AIC Calculated =1357.6315811773306
# ARIMA (2, 2, 2) x (1, 1, 1, 1)12 : AIC Calculated =1331.978081582629
# ARIMA (2, 2, 2) x (1, 1, 2, 1)12 : AIC Calculated =1315.0939363042542
# ARIMA (2, 2, 2) x (1, 2, 0, 1)12 : AIC Calculated =1418.9679240970304
# ARIMA (2, 2, 2) x (1, 2, 1, 1)12 : AIC Calculated =1337.0036309676716
# ARIMA (2, 2, 2) x (1, 2, 2, 1)12 : AIC Calculated =1340.7078373327013
# ARIMA (2, 2, 2) x (2, 0, 0, 1)12 : AIC Calculated =1337.3795177311918
# ARIMA (2, 2, 2) x (2, 0, 1, 1)12 : AIC Calculated =1338.867110883902
# ARIMA (2, 2, 2) x (2, 0, 2, 1)12 : AIC Calculated =1328.9130143025961
# ARIMA (2, 2, 2) x (2, 1, 0, 1)12 : AIC Calculated =1365.6086050409822
# ARIMA (2, 2, 2) x (2, 1, 1, 1)12 : AIC Calculated =1337.2919413252794
# ARIMA (2, 2, 2) x (2, 1, 2, 1)12 : AIC Calculated =1317.6250976904146
# ARIMA (2, 2, 2) x (2, 2, 0, 1)12 : AIC Calculated =1359.706918699596
# ARIMA (2, 2, 2) x (2, 2, 1, 1)12 : AIC Calculated =1349.7164102006789
# ARIMA (2, 2, 2) x (2, 2, 2, 1)12 : AIC Calculated =1327.9885445973082

# %%
# Find the parameters with minimal AIC value
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq        (1, 1, 2)
# pdqs    (2, 2, 2, 1)
# aic          1314.92
# Name: 404, dtype: object

# %%
# Plug the optimal parameter values into a new SARIMAX model
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(ts1, 
                                        order=(1, 1, 2), 
                                        seasonal_order=(2, 2, 2, 1), 
                                        enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and print results
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3402      0.273      1.249      0.212      -0.194       0.874
# ma.L1         -0.9235     27.985     -0.033      0.974     -55.772      53.925
# ma.L2         -0.0529     27.454     -0.002      0.998     -53.863      53.757
# ar.S.L1        0.6746      0.337      2.002      0.045       0.014       1.335
# ar.S.L2       -0.4779      0.193     -2.475      0.013      -0.857      -0.099
# ma.S.L1       -0.8343     28.487     -0.029      0.977     -56.669      55.000
# ma.S.L2       -0.0381     25.137     -0.002      0.999     -49.306      49.230
# sigma2      2.978e+05   5.02e+04      5.936      0.000    1.99e+05    3.96e+05
# ==============================================================================

# %%
# Call plot_diagnostics() on the results calculated above 
output.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# ## One-step Ahead Forecasting

# %%
# Get predictions starting from 01-01-1998 and calculate confidence intervals
pred = output.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False)
pred_conf = pred.conf_int()

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

# Plot observed values
ax = ts1['2010-01-01':].plot(label='observed')

# Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=0.9)

# Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='g', alpha=0.5)

# Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %%
# pred.predicted_mean

# %%
# Get the real and predicted values
ts1_forecasted = pred.predicted_mean
ts1_truth = ts1['2016-01-01':]
mse = mean_squared_error(ts1_truth, ts1_forecasted)
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 668.64

# %% [markdown]
# ## Dynamic Forecasting

# %%
# Get dynamic predictions with confidence intervals as above 
pred_dynamic = output.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=True, full_results=True)
pred_dynamic_conf = pred_dynamic.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals.

ax = ts1['2010':].plot(label='observed', figsize=(20, 15))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_conf.index,
                pred_dynamic_conf.iloc[:, 0],
                pred_dynamic_conf.iloc[:, 1], color='g', alpha=.3)


ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2016-01-01'), ts1_forecasted.index[-1], alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %%
# Get the real and predicted values
ts1_forecasted = pred_dynamic.predicted_mean
ts1_truth = ts1['2016-01-01':]
mse = mean_squared_error(ts1_truth, ts1_forecasted)
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 15110.74

# %%
print(mse)
# Out:
# 41249183.489025325

# %% [markdown]
# ## Producing and visualising forecasts

# %%
# Get forecast 500 steps ahead in future
prediction = output.get_forecast(steps=24)

# Get confidence intervals of forecasts
pred_conf = prediction.conf_int()

# %%
# Plot future predictions with confidence intervals
ax = ts1.plot(label='observed', figsize=(20, 15))
prediction.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='k', alpha=0.25)
ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %%
prediction.predicted_mean['2020-01-01']
# Out:
# 128802.58024216679

# %%
# ROI
print((prediction.predicted_mean['2020-01-01']/ts1['2018-01'])-1)
# Out:
#                value
# time
# 2018-01-01  0.401551
